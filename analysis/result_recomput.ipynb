# %%
path = '/home/users/jiangjin/jiangjin_bupt/ASR_CORRECTION/Context_Correction/context_seq2seq/T-model-knn-ckpt/AISHELL-1/result/T_modal_AISHELL-1.txt'

# %%
with open(path, 'r') as f_data:
    data = f_data.readlines()

# %%
len(data)
# Out:
# 7480

# %%
data[0]
# Out:
# '甚至出现交易几乎停滞的情况。 甚至出现交易几乎停滞的情况。\n'

# %%
data[0]
# Out:
# '甚至出现交易几乎停滞的情况。 甚至出现交易几乎停滞的情况。\n'

# %%
result_data = data
result_label = [item.strip().split(' ')[1] for item in result_data]

# %%
len(result_label)
# Out:
# 7480

# %%
path_data = '/home/users/jiangjin/jiangjin_bupt/ASR_CORRECTION/Context_Correction/context_seq2seq/data/zh/AISHELL-1/AISHELL-1_test.txt'

# %%
with open(path_data, 'r') as f_data:
    raw_data = f_data.readlines()

# %%
raw_data[0].split(' ')
# Out:
# ['BAC009S0764W0121', '甚至出现交易几乎停滞的情况。', '甚至出现交易几乎停滞的情况。\n']

# %%
raw_label = [item.split(' ')[1] for item in raw_data]
raw_record = [item.strip().split(' ')[2] for item in raw_data]

# %%
'上海南昌等城市近期继续松绑了公积金贷款政策。' in raw_label
# Out:
# True

# %%
for item in raw_label:
    if item not in result_label:
        print(item)
# Out:
# 村卫生室医师兼职黑Ｂ超记者暗访结束被跟踪。
# 明着是大兴区黄村镇狼垡三村的医师。
# 高桥大辅则是噘着嘴做出索吻的动作。
# 陈冠希坦言认为陈奕迅是Ｋ歌之王。
# 由二十二栋企业独栋和二栋二十层的五Ａ级写字楼组成。

# %%
# data_new = [item for item in data if item not in data_new]
data_label_new = []
for item in result_data:
    # item = 
    if item.strip().split(' ')[1] != '钢筋穿过后排座位并顶出车外。':
        
        data_label_new.append(item)
    else:
        print(item)
# Out:
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# 钢筋穿过后排座位并顶出车外。 钢筋穿过后排座位并顶出车外。
#
# ...

# %%
# data_new = [item for item in data if item not in data_new]
data_reord_new = []
for item in result_label:
    # item = 
    if item.strip() != '钢筋穿过后排座位并顶出车外。':
        
        data_label_new.append(item)
    else:
        print(item)

# %%
'上海南昌等城市近期继续松绑了公积金贷款政策。' in data_new
# Out:
# True

# %%
len(data_label_new)
# Out:
# 7196

# %%
from collections import Counter
 
a = raw_label
b = dict(Counter(a))
# print ([key for key,value in b.items()if value > 1]) #只展示重复元素
print ({key:value for key,value in b.items()if value > 1}) #展现重复元素和重复次数
# Out:
# {'稳增长措施需更全面地考虑化解楼市风险问题。': 2, '相关公司股票走势农产品。': 2, '因为难以忍受股价长期被低估。': 2, '中国游戏公司纷纷忙着退市。': 2, '北京商报讯记者王晔君日前。': 2, '好莱坞当红明星之前曾被盛传将扮演斯诺登。': 2, '搜狐娱乐讯据台湾媒体报道。': 6, '永远的紫霞仙子朱茵的亮相引起粉丝的热捧。': 2, '相关公司股票走势。': 2, '点击进入股友会参与讨论。': 2, '他就上述关注问题指出。': 2, '目前我国出现政府性债务违约可能性并不大。': 2, '并尽快建立我国地方政府债务管理体系等。': 2, '政府性违约可能性不大。': 2, '您如何看待政府的举债行为和债务风险。': 2, '徐林吸取欧美等国主权债务危机的教训。': 2, '采取必要措施加强政府债务管理。': 2, '防范我国政府债务风险。': 2, '但在具体评估我国地方政府债务风险程度时。': 2, '也要看到我国与欧美国家的不同之处。': 2, '我国地方政府性债务。': 2, '当代人和后代人共同承担债务还本付息责任。': 2, '可以更好地体现代际公平。': 2, '克服当期建设资金不足的瓶颈制约。': 2, '有利于加快完善基础设施和投资环境。': 2, '相当部分资产具有长期的直接收益。': 2, '一些没有直接收益的项目。': 2, '也具有间接的经济效益或社会效益。': 2, '对促进当地经济增长和政府财力的增长。': 2, '不能简单地用寅吃卯粮来作价值判断。': 2, '这并不意味着政府可以无节制地借债。': 2, '关键是要把投资规模和债务规模。': 2, '控制在合理的范围内。': 2, '防止出现系统性的偿债风险。': 2, '国务院高度重视防范地方政府债务风险。': 2, '从二零零九年下半年就开始要求有关部门调研这一问题。': 2, '国家审计署还专门组织力量。': 2, '审计署的审计结论表明。': 2, '我国地方政府的累积债务相对于偿付能力来看。': 2, '远低于发生债务危机的欧美国家。': 4, '考虑到我国正处在经济快速增长期。': 2, '政府还拥有较多的可变现资产。': 2, '相对于目前的负债规模。': 2, '政府总体上具有较强的偿债能力。': 2, '采取积极有效的措施化解部分
# ...

# %%
keys = [key for key,value in b.items()if value > 1]
values = [key for key,value in b.items()if value > 1]

# %%
len(keys)
# Out:
# 240

# %%
from datasets import load_metric
metric  = load_metric('cer')
# Out:
# /tmp/ipykernel_12937/632148419.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric  = load_metric('cer')
# Using the latest cached version of the module from /home/users/jiangjin/.cache/huggingface/modules/datasets_modules/metrics/cer/0d603b79fde740594c09751048122254b33a79b1c45328bd72ca604534ce8156 (last modified on Tue Dec 14 16:32:40 2021) since it couldn't be found locally at cer, or remotely on the Hugging Face Hub.

# %%
label = [item.strip().split(' ')[1] for item in data_label_new]
record = [item.strip().split(' ')[0] for item in data_label_new]

# %%
value = metric.compute(references=label,predictions=record)
value
# Out:
# 0.03628461243865727

# %%
data_new_norepeat = []
for item in data_new:
    if item not in data_new_norepeat:
        data_new_norepeat.append(item)
    else:
        print(item)
# Out:
# 上海南昌等城市近期继续松绑了公积金贷款政策。
# 进而选择此类方式购房。
# 而南昌除了放松首套房界定标准。
# 另外要处理公积金异地使用的问题。
# 公积金贷款额度的提高。
# 这对于目前一线城市来说很紧要。
# 很多人受限购政策的影响。
# 难以在周边城市用公积金购房。
# 导致公积金资源闲置的问题出现。
# 以住房公积金制度为基础。
# 随着广州住房公积金贷款政策的调整实施。
# 随着广州住房公积金贷款政策的调整实施。
# 住建部等三部委联合发文。
# 美丽北京大型绿色公益品牌项目。
# 再次降低公积金贷款的门槛。
# 还清首套房公积金贷款。
# 美丽北京大型绿色公益品牌项目。
# 在公积金贷款额度上调后一个月内。
# 随着广州住房公积金贷款政策的调整实施。
# 北京公积金贷款成交量上涨百分之五。
# 国家统计局公布的数据显示。
# 住房公积金贷款因其利率较低的优势。
# 一直以来广受购房者青睐。
# 进一步加速了消费者的入市节奏。
# 支持新产业新业态。
# 北京去年土地出让落下大幕。
# 广州调整住房公积金个人住房贷款政策。
# 北京今年的土地出让金锁定在两千亿元。
# 据广州日报昨天报道。
# 公积金贷款首付比例降低的消息令购房者喜出望外。
# 美丽北京大型绿色公益品牌项目。
# 据伟嘉安捷提供的数据显示。
# 北京公积金贷款首付比例松绑一周后。
# 公积金贷款及组合贷咨询量明显上涨。
# 对于实施住房限购政策的城市。
# 市政府决定今年将全面加快棚户区改造步伐。
# 上海深圳等主要城市也在公积金新政推动下。
# 境外个人购房应当符合当地政策规定。
# 一线城市土地市场成交火热。
# 确保完成六万户搬迁改造任务。
# 房地产相关领域问题频发。
# 自二夏季开始。
# 中介机构统计数据显示。
# 全国已有超百个城市发布了不同力度的公积金松绑政策。
# 得益于一系列稳定房地产市场的措施。
# 加之降息降准等政策组合拳。
# 审计署审计长刘家义受国务院委托。
# 为促进房地产市场平稳健康发展。
# 兰州房地产市场销量增加明显。
# 呈现出量价齐涨的局面。
# 据中国指数研究院最新数据显示。
# 二初楼市迎来多项利好政策。
# 相关公司股票走势。
# 盘活各地公积金资源。
# 在多项政策的支持下。
# 涨幅据十大城市之首。
# ...

# %%
len(data_new_norepeat)
# Out:
# 6848
